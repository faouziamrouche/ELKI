# %%
import pandas as pd

# LOF = pd.read_csv("LOF/result-2.csv", header=None)
# data = pd.read_csv("./../data-ready.csv")
LoOP = pd.read_csv("LoOP/result-1.csv", header=None)

# %%
# LOF
data
# Out:
#       Unnamed: 0    ID  Reste ÌÊ vivre mensuel  Taux d'apport  \
# 0           1499     2             5321.000000          19.44
# 1            982     3             5267.000000          25.00
# 2           2831     7             2885.000000          38.89
# 3           1636     8             1860.000000          15.87
# 4            434    14             4538.000000          32.86
# ...          ...   ...                     ...            ...
# 2494         581  7923             4060.000000           4.00
# 2495        2732  7930             1374.000000          20.00
# 2496        1675  7931             2104.000000          20.00
# 2497         862  7938             2283.768086           0.00
# 2498         290  7939             3357.000000          15.00
#
#       Revenus du foyer  Taux d'endettement  Prix_immobilier  Apport global  \
# 0              6213.60           14.360000    180000.000000    35000.00000
# ...

# %%
LoOP
# Out:
#                                       0
# 0      loop-outlier=0.12081777707620542
# 1       loop-outlier=0.3450228972133744
# 2                      loop-outlier=0.0
# 3     loop-outlier=0.027832066720627692
# 4        loop-outlier=0.467164476208383
# ...                                 ...
# 2494                   loop-outlier=0.0
# 2495                   loop-outlier=0.0
# 2496                   loop-outlier=0.0
# 2497    loop-outlier=0.5075696074113997
# 2498                   loop-outlier=0.0
#
# [2499 rows x 1 columns]
